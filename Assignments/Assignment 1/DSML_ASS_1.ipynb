# %% [markdown]
# **DSML ASSIGNMENT 1**
#
# ---

# %%
import numpy as np
import pandas as pd

# %%
# a) read data from different formats (like csv, xls)
obj = pd.read_csv("/content/Heart.csv")
# print(obj.head())
obj.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
# b) indexing and selecting data, sort data,
# 1. by using rowindex columnindex number[.iloc]
obj.iloc[0:15,5:]
# Out:
#     Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0    233    1        2    150      0      2.3      3  0.0       fixed   No
# 1    286    0        2    108      1      1.5      2  3.0      normal  Yes
# 2    229    0        2    129      1      2.6      2  2.0  reversable  Yes
# 3    250    0        0    187      0      3.5      3  0.0      normal   No
# 4    204    0        2    172      0      1.4      1  0.0      normal   No
# 5    236    0        0    178      0      0.8      1  0.0      normal   No
# 6    268    0        2    160      0      3.6      3  2.0      normal  Yes
# 7    354    0        0    163      1      0.6      1  0.0      normal   No
# 8    254    0        2    147      0      1.4      2  1.0  reversable  Yes
# 9    203    1        2    155      1      3.1      3  0.0  reversable  Yes
# 10   192    0        0    148      0      0.4      2  0.0       fixed   No
# ...

# %%
# 2. using loc
obj.loc[[0,5]]
# Out:
#    Unnamed: 0  Age  Sex   ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0           1   63    1     typical     145   233    1        2    150      0
# 5           6   56    1  nontypical     120   236    0        0    178      0
#
#    Oldpeak  Slope   Ca    Thal AHD
# 0      2.3      3  0.0   fixed  No
# 5      0.8      1  0.0  normal  No

# %%
# sorting data
obj.sort_values(by="Age")
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 132         133   29    1    nontypical     130   204    0        2    202
# 101         102   34    1       typical     118   182    0        2    174
# 225         226   34    0    nontypical     118   210    0        0    192
# 283         284   35    1    nontypical     122   192    0        0    174
# 117         118   35    0  asymptomatic     138   183    0        0    182
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 42           43   71    0    nontypical     160   302    0        0    162
# 103         104   71    0    nonanginal     110   265    1        2    130
# 233         234   74    0    nontypical     120   269    0        2    121
# 257         258   76    0    nonanginal     140   197    0        1    116
# 161         162   77    1  asymptomatic     125   304    0        2    162
#
#      ExAng  Oldpeak  Slope   Ca    Thal  AHD
# ...

# %%
# c) describe attributes of data, checking data types of each column
# 1. describe :-
print(obj.describe())
print(obj.info())
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
# 2. checking data types of columns
type(obj.iloc[0: ,0:])
# Out:
# pandas.core.frame.DataFrame

# %%
# d) counting unique values of data, format of each column, converting variable data type (e.g.
# from long to short, vice versa),

# 1. counting unique values of data -
obj.value_counts()
# Out:
# Unnamed: 0  Age  Sex  ChestPain     RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope  Ca   Thal        AHD
# 1           63   1    typical       145     233   1    2        150    0      2.3      3      0.0  fixed       No     1
# 208         50   1    asymptomatic  144     200   0    2        126    1      0.9      2      0.0  reversable  Yes    1
# 206         45   1    asymptomatic  142     309   0    2        147    1      0.0      2      3.0  reversable  Yes    1
# 205         43   1    asymptomatic  110     211   0    0        161    0      0.0      1      0.0  reversable  No     1
# 204         64   0    nonanginal    140     313   0    0        133    0      0.2      1      0.0  reversable  No     1
#                                                                                                                      ..
# 101         45   1    asymptomatic  115     260   0    2        185    0      0.0      1      0.0  normal      No     1
# ...

# %%
# 2. formating of column

df = pd.DataFrame({'Product': ['Apples', 'Oranges', 'Bananas'], 'Price': [60, 80, 40]})
df.style.format({'Price': '₹ {}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe776" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe776_level0_col0" class="col_heading level0 col0" >Product</th>
#       <th id="T_fe776_level0_col1" class="col_heading level0 col1" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe776_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe776_row0_col0" class="data row0 col0" >Apples</td>
#       <td id="T_fe776_row0_col1" class="data row0 col1" >₹ 60</td>
#     </tr>
#     <tr>
#       <th id="T_fe776_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe776_row1_col0" class="data row1 col0" >Oranges</td>
#       <td id="T_fe776_row1_col1" class="data row1 col1" >₹ 80</td>
#     </tr>
#     <tr>
#       <th id="T_fe776_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe776_row2_col0" class="data row2 col0" >Bananas</td>
# ...

# %%
# c. converting variable data type (e.g.from long to short, vice versa),
var = np.arange(0,20).reshape(4,5)
var1 = pd.DataFrame(var,index=["row1","row2","row3","row4"], columns=["col1","col2","col3","col4","col5"])
var1
var1 = var1.astype(float)
var1
# data type changed from int to float
# Out:
#       col1  col2  col3  col4  col5
# row1   0.0   1.0   2.0   3.0   4.0
# row2   5.0   6.0   7.0   8.0   9.0
# row3  10.0  11.0  12.0  13.0  14.0
# row4  15.0  16.0  17.0  18.0  19.0

# %%
# D. identifying missing values and fill in the missing values
sdf = pd.DataFrame([[1,np.nan,3,4],[3,4,0,np.nan]],index=["r1","r2"],columns=["c1","c2","c3","c4"])

# identifying null missing values
print(sdf.isnull())

# filling missing values with 0
print(sdf.fillna("Zero"))
# Out:
#        c1     c2     c3     c4
# r1  False   True  False  False
# r2  False  False  False   True
#     c1    c2  c3    c4
# r1   1  Zero   3   4.0
# r2   3   4.0   0  Zero
